# %%
import pandas as pd
import numpy as np

# %%
#!pip install mlxtend

# %%
dataset1=pd.read_csv("prep.csv",index_col=None)
df2=dataset1
df2 = pd.get_dummies(df2, drop_first=True)

X=df2.drop('classification_yes', axis=1)
y=df2['classification_yes']

# %%
X.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes'],
#       dtype='object')

# %%
df2.head()
# Out:
#    age         bp   al   su         bgr         bu        sc         sod  \
# 0  2.0  76.459948  3.0  0.0  148.112676  57.482105  3.077356  137.528754
# 1  3.0  76.459948  2.0  0.0  148.112676  22.000000  0.700000  137.528754
# 2  4.0  76.459948  1.0  0.0   99.000000  23.000000  0.600000  138.000000
# 3  5.0  76.459948  1.0  0.0  148.112676  16.000000  0.700000  138.000000
# 4  5.0  50.000000  0.0  0.0  148.112676  25.000000  0.600000  137.528754
#
#         pot       hrmo  ...  pc_normal  pcc_present  ba_present  htn_yes  \
# 0  4.627244  12.518156  ...      False        False       False    False
# 1  4.627244  10.700000  ...       True        False       False    False
# 2  4.400000  12.000000  ...       True        False       False    False
# 3  3.200000   8.100000  ...       True        False       False    False
# 4  4.627244  11.800000  ...       True        False       False    False
#
#    dm_yes  cad_yes  appet_yes  pe_yes  ane_yes  classification_yes
# ...

# %%
df2.shape
# Out:
# (399, 28)

# %%
df2.isnull().sum()
# Out:
# age                   0
# bp                    0
# al                    0
# su                    0
# bgr                   0
# bu                    0
# sc                    0
# sod                   0
# pot                   0
# hrmo                  0
# pcv                   0
# wc                    0
# rc                    0
# sg_b                  0
# sg_c                  0
# sg_d                  0
# sg_e                  0
# rbc_normal            0
# pc_normal             0
# pcc_present           0
# ba_present            0
# htn_yes               0
# dm_yes                0
# cad_yes               0
# appet_yes             0
# pe_yes                0
# ane_yes               0
# classification_yes    0
# dtype: int64

# %%
X.shape, y.shape
# Out:
# ((399, 27), (399,))

# %%
from mlxtend.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression(solver='lbfgs')
sfs1 = SequentialFeatureSelector(log_model,k_features=10, forward=True, floating=False, verbose=0, scoring=None, cv=5, n_jobs=1, pre_dispatch='2n_jobs', clone_estimator=True, fixed_features=None, feature_groups=None)

# %%
sfs1 = sfs1.fit(X, y)
sfs1
# Out:
# C:\Users\swath\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# C:\Users\swath\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# C:\Users\swath\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# C:\Users\swath\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:73: FutureWarning: `fit_params` is deprecated and will be removed in version 1.6. Pass parameters via `params` instead.
#   warnings.warn(
# ...

# %%
sfs2=sfs1.transform(X)
sfs2
# Out:
# array([[3.0, 0.0, 4.62724358974359, ..., True, False, False],
#        [2.0, 0.0, 4.62724358974359, ..., True, False, True],
#        [1.0, 0.0, 4.4, ..., False, False, True],
#        ...,
#        [3.0, 0.0, 2.7, ..., True, False, True],
#        [0.0, 0.0, 5.5, ..., False, False, True],
#        [0.0, 0.0, 5.0, ..., False, False, True]], dtype=object)

# %%
sfs2.shape
# Out:
# (399, 10)

# %%
sfs1.k_feature_idx_
# Out:
# (2, 3, 8, 9, 10, 12, 13, 14, 15, 18)

# %%
sfs1.k_score_
# Out:
# 0.975

# %%
sfs1.subsets_
# Out:
# {1: {'feature_idx': (9,),
#   'cv_scores': array([0.85      , 0.9375    , 0.8625    , 0.95      , 0.98734177]),
#   'avg_score': 0.9174683544303799,
#   'feature_names': ('hrmo',)},
#  2: {'feature_idx': (2, 9),
#   'cv_scores': array([0.9   , 0.9625, 0.9   , 0.975 , 1.    ]),
#   'avg_score': 0.9475000000000001,
#   'feature_names': ('al', 'hrmo')},
#  3: {'feature_idx': (2, 3, 9),
#   'cv_scores': array([0.9   , 0.9875, 0.9375, 0.975 , 1.    ]),
#   'avg_score': 0.9600000000000002,
#   'feature_names': ('al', 'su', 'hrmo')},
#  4: {'feature_idx': (2, 3, 9, 10),
#   'cv_scores': array([0.9125, 0.9875, 0.975 , 0.975 , 1.    ]),
#   'avg_score': 0.97,
#   'feature_names': ('al', 'su', 'hrmo', 'pcv')},
#  5: {'feature_idx': (2, 3, 9, 10, 15),
#   'cv_scores': array([0.925 , 0.9875, 0.975 , 0.975 , 1.    ]),
#   'avg_score': 0.9725000000000001,
#   'feature_names': ('al', 'su', 'hrmo', 'pcv', 'sg_d')},
#  6: {'feature_idx': (2, 3, 9, 10, 15, 18),
# ...

# %%
sfs1.get_metric_dict(confidence_interval=0.95)
# Out:
# {1: {'feature_idx': (9,),
#   'cv_scores': array([0.85      , 0.9375    , 0.8625    , 0.95      , 0.98734177]),
#   'avg_score': 0.9174683544303799,
#   'feature_names': ('hrmo',),
#   'ci_bound': 0.06780532260180458,
#   'std_dev': 0.05275484457394857,
#   'std_err': 0.026377422286974286},
#  2: {'feature_idx': (2, 9),
#   'cv_scores': array([0.9   , 0.9625, 0.9   , 0.975 , 1.    ]),
#   'avg_score': 0.9475000000000001,
#   'feature_names': ('al', 'hrmo'),
#   'ci_bound': 0.05220876388742254,
#   'std_dev': 0.04062019202317979,
#   'std_err': 0.020310096011589895},
#  3: {'feature_idx': (2, 3, 9),
#   'cv_scores': array([0.9   , 0.9875, 0.9375, 0.975 , 1.    ]),
#   'avg_score': 0.9600000000000002,
#   'feature_names': ('al', 'su', 'hrmo'),
#   'ci_bound': 0.04700546292009111,
#   'std_dev': 0.03657184709581948,
#   'std_err': 0.018285923547909737},
#  4: {'feature_idx': (2, 3, 9, 10),
#   'cv_scores': array([0.9125, 0.9875, 0.975 , 0.975 , 1.    ]),
#   'avg_score': 0.97,
# ...

# %%
op=list(sfs1.k_feature_names_)
op
# Out:
# ['al', 'su', 'pot', 'hrmo', 'pcv', 'rc', 'sg_b', 'sg_c', 'sg_d', 'pc_normal']

# %%
Indep_X = df2[op]
Dep_Y = df2['classification_yes']

# %%
Indep_X
# Out:
#       al   su       pot       hrmo        pcv        rc   sg_b   sg_c   sg_d  \
# 0    3.0  0.0  4.627244  12.518156  38.868902  4.705597  False   True  False
# 1    2.0  0.0  4.627244  10.700000  34.000000  4.705597  False   True  False
# 2    1.0  0.0  4.400000  12.000000  34.000000  4.705597  False  False  False
# 3    1.0  0.0  3.200000   8.100000  38.868902  4.705597  False  False   True
# 4    0.0  0.0  4.627244  11.800000  36.000000  4.705597  False   True  False
# ..   ...  ...       ...        ...        ...       ...    ...    ...    ...
# 394  0.0  0.0  3.700000  12.500000  37.000000  4.400000  False  False  False
# 395  0.0  2.0  4.627244   8.700000  27.000000  4.705597  False   True  False
# 396  3.0  0.0  2.700000   9.100000  26.000000  3.400000  False   True  False
# 397  0.0  0.0  5.500000   8.500000  38.868902  4.705597  False  False  False
# 398  0.0  0.0  5.000000  16.300000  53.000000  4.900000  False  False  False
#
#      pc_normal
# 0        False
# ...

# %%
Indep_X.shape, X.shape
# Out:
# ((399, 10), (399, 27))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sfs2, Dep_Y, test_size = 0.25, random_state = 0)

# %%
X_train.shape
# Out:
# (299, 10)

# %%
X_test.shape
# Out:
# (100, 10)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.14783985, -0.36317599, -0.26811455, ...,  1.91621371,
#         -0.46416285,  0.49581583],
#        [-0.65587132, -0.36317599, -0.36295635, ..., -0.52186246,
#         -0.46416285,  0.49581583],
#        [-0.65587132, -0.36317599, -0.31553545, ..., -0.52186246,
#         -0.46416285,  0.49581583],
#        ...,
#        [-0.65587132, -0.36317599, -0.17327274, ..., -0.52186246,
#          2.15441626, -2.01687794],
#        [-0.65587132, -0.36317599,  0.20609447, ..., -0.52186246,
#         -0.46416285,  0.49581583],
#        [-0.65587132, -0.36317599,  0.20609447, ..., -0.52186246,
#         -0.46416285,  0.49581583]])

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)
        
        # Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
        
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
        
Accuracy=accuracy_score(y_test, y_pred )
        
report=classification_report(y_test, y_pred)

# %%
Accuracy
# Out:
# 0.99
